# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install opencv-python
# !pip install matplotlib
# !pip install pillow
# !pip install scikit-image
# !pip install numpy
# Out:
# Requirement already satisfied: opencv-python in .\.conda\envs\lab1\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in .\.conda\envs\lab1\lib\site-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: matplotlib in .\.conda\envs\lab1\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in .\.conda\envs\lab1\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in .\.conda\envs\lab1\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\.conda\envs\lab1\lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.conda\envs\lab1\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in .\.conda\envs\lab1\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in .\.conda\envs\lab1\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in .\.conda\envs\lab1\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in .\.conda\envs\lab1\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in .\.conda\envs\lab1\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\.conda\envs\lab1\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pillow in .\.conda\envs\lab1\lib\site-packages (11.1.0)
# Requirement already satisfied: scikit-image in .\.conda\envs\lab1\lib\site-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in .\.conda\envs\lab1\lib\site-packages (from scikit-image) (2.2.6)
# Requirement already satisfied: scipy>=1.11.4 in .\.conda\envs\lab1\lib\site-packages (from scikit-image) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in .\.conda\envs\lab1\lib\site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in .\.conda\envs\lab1\lib\site-packages (from scikit-image) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in .\.conda\envs\lab1\lib\site-packages (from scikit-image) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in .\.conda\envs\lab1\lib\site-packages (from scikit-image) (2025.2.18)
# Requirement already satisfied: packaging>=21 in .\.conda\envs\lab1\lib\site-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in .\.conda\envs\lab1\lib\site-packages (from scikit-image) (0.4)
# Requirement already satisfied: numpy in .\.conda\envs\lab1\lib\site-packages (2.2.6)

# %%
from skimage import data
import matplotlib.pyplot as plt

img = data.camera()
plt.imshow(img, cmap='gray')
plt.show()

# %%
print(img.shape)
print(img)
# Out:
# (512, 512)
# [[200 200 200 ... 189 190 190]
#  [200 199 199 ... 190 190 190]
#  [199 199 199 ... 190 190 190]
#  ...
#  [ 25  25  27 ... 139 122 147]
#  [ 25  25  26 ... 158 141 168]
#  [ 25  25  27 ... 151 152 149]]

# %%
import cv2

cv2.imwrite('new_image.jpg', img)
# Out:
# True

# %%
print(img.shape)
print(img)
# Out:
# (512, 512)
# [[200 200 200 ... 189 190 190]
#  [200 199 199 ... 190 190 190]
#  [199 199 199 ... 190 190 190]
#  ...
#  [ 25  25  27 ... 139 122 147]
#  [ 25  25  26 ... 158 141 168]
#  [ 25  25  27 ... 151 152 149]]

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

img2 = Image.fromarray(img)

plt.imshow(img2, cmap=cm.Greys_r)
plt.title("Image using PIL")
plt.show()

# %%
img_array = np.array(img2)

print(img_array.shape)
print(img_array)
# Out:
# (512, 512)
# [[200 200 200 ... 189 190 190]
#  [200 199 199 ... 190 190 190]
#  [199 199 199 ... 190 190 190]
#  ...
#  [ 25  25  27 ... 139 122 147]
#  [ 25  25  26 ... 158 141 168]
#  [ 25  25  27 ... 151 152 149]]
